# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import datetime

# %%
URL = "https://www.amazon.in/s?k=iphone&crid=3UKKNKQT5XYKI&sprefix=iphon%2Caps%2C273&ref=nb_sb_ss_pltr-xclick_2_5"

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36 Edg/126.0.0.0"}

# %%
webpage = requests.get(URL,headers= headers)
webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
links = soup.find_all('a',attrs={"class":"a-link-normal s-no-outline"})
print(links)
# Out:
# [<a class="a-link-normal s-no-outline" href="/sspa/click?ie=UTF8&amp;spc=MTo0NDA0MTYwNzIxMjAxMjk2OjE3NDg4NTY0Mzg6c3BfYXRmOjMwMDA1NDM0NTk0NzYzMjo6MDo6&amp;url=%2FApple-iPhone-15-128-GB%2Fdp%2FB0CHX1W1XY%2Fref%3Dsr_1_1_sspa%3Fcrid%3D3UKKNKQT5XYKI%26dib%3DeyJ2IjoiMSJ9.vB_DQIqpBbU0gO5332epH6WDoB5h-9C6cHAj-CJcKngL1me6rw8OXNrOi1LBmMiU4fM-zTgrz66bwWwil1bZktzddPEgkXUmWBdMRQ7hN7tl1egDYkP4PpdShIwSKrBqZ8YjSKLD5C7PHSE1vFj2wFZ-HdaGO57tq72Dx3BQ1RNDwT3TKlHdEmsXl37uFtCe-2V9SfXZ3xyqheAg8hOe_RrKVSy6J0YpO0ZqghoIHcI.k9ZvW6QzCYFldC_jSbpAES8tEcKh-wuR9udmukUxgXc%26dib_tag%3Dse%26keywords%3Diphone%26qid%3D1748856438%26sprefix%3Diphon%252Caps%252C273%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1" tabindex="-1" target="_blank"><div class="a-section aok-relative s-image-fixed-height"><img alt="Sponsored Ad - Apple iPhone 15 (128 GB) - Black" aria-hidden="true" class="s-image" data-image-index="1" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://
# ...

# %%
def get_title(soup2):
    try:
        title = soup2.find("span",attrs={"id":"productTitle"}).text.strip()
        return title
    except Exception:
        return ""

def get_price(soup2):
    try:
        price = soup2.find("span",attrs={"class":"a-price-whole"}).text.strip()
        return price
    except Exception:
        return ""

def get_ratings(soup2):
    try:
        ratings = soup2.find("span",attrs={"class":"a-icon-alt"}).text.strip()
        return ratings
    except Exception:
        return ""

def get_reviews(soup2):
    try:
        reviews = soup2.find("span",attrs={"id":"acrCustomerReviewText"}).text.strip()
        return reviews
    except Exception:
        return ""

def get_availability(soup2):
    try:
        availability = soup2.find("span",attrs={"class":"a-size-medium a-color-success"}).text.strip()
        return availability
    except Exception:
        return ""

# %%
import pandas as pd

product_link = []
for link in links:
    href = link.get("href")
    if href.startswith("/"):
        product_link.append("https://www.amazon.in" + href)
    else:
        continue

details = {"title":[], "price":[], "ratings":[], "reviews":[], "availability":[]}

for link in product_link:
    new_webpage = requests.get(link,headers=headers)
    soup2 = BeautifulSoup(new_webpage.content, "html.parser")

    details['title'].append(get_title(soup2))
    details['price'].append(get_price(soup2))
    details['ratings'].append(get_ratings(soup2))
    details['reviews'].append(get_reviews(soup2))
    details['availability'].append(get_availability(soup2))

df = pd.DataFrame(details)
Amazon_csv = df.to_csv("C:/Users/jkrat/Downloads/amazon_iphone_data.csv", header = True, index = False)
df
# Out:
#                                                 title      price  \
# 0                    Apple iPhone 15 (128 GB) - Black    59,500.
# 1   iPhone 16 128 GB: 5G Mobile Phone with Camera ...    73,500.
# 2   iPhone 16 Pro Max 256 GB: 5G Mobile Phone with...  1,35,900.
# 3                    Apple iPhone 15 (128 GB) - Black    59,500.
# 4                     Apple iPhone 15 (128 GB) - Pink    59,500.
# 5                     Apple iPhone 15 (128 GB) - Blue    59,700.
# 6   iPhone 16 128 GB: 5G Mobile Phone with Camera ...    73,500.
# 7                     Apple iPhone 15 (256 GB) - Blue    69,200.
# 8                    Apple iPhone 15 (256 GB) - Black    69,200.
# 9                    Apple iPhone 13 (512 GB) - Green    60,900.
# 10                Apple iPhone 13 (512GB) - Starlight    60,900.
# 11  iPhone 16e 128 GB: Built for Apple Intelligenc...    53,600.
# 12                   Apple iPhone 15 (128 GB) - Green    59,900.
# ...
